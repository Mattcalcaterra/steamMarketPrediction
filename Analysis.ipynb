# %%
# SI 618 Final Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import json
import requests

# %% [markdown]
# ## Steam Store Reviews Data
#
# Data for the review for each game in the steam store can be scraped from the web from the base url: `https://store.steampowered.com/appreviews/<appid>?json=1`
#
# This data is returned in the form of a json file

# %%
def get_steam_reviews(
    appid,
    params={
        "json": 1,
        "filter": "all",
        "language": "english",
    },
):
    """
    Get Steam reviews for a specific game/app by scraping the steamstore website endpoint

    Parameters
    ----------
    appid : int
            Steam app id
    params : dict
            Parameters to pass to API call

    Returns
    -------
    json
            Steam reviews as json
    """
    base_url = "https://store.steampowered.com/appreviews/"

    # Uses a header to avoid being timed out by steam
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"
    }

    # Call API
    response = requests.get(
        base_url + str(appid), headers=headers, params=params
    )

    # Return as  json
    return response.json()

# %%
def get_n_reviews(appid, n=100):
    """
    Function code orginially written by Andrew Muller at https://andrew-muller.medium.com/scraping-steam-user-reviews-9a43f9e38c92

    The most reviews that can be returned at once is 100. This function will return n reviews for a given appid by using the cursor to get the next 100 reviews until n reviews have been returned.

    Parameters
    ----------
    appid : int
        The appid of the game to get reviews for
    n : int
        The number of reviews to return

    Returns
    -------
    reviews : list
        A list of dictionaries containing the reviews

    """
    reviews = []
    cursor = "*"
    params = {
        "json": 1,
        "filter": "all",
        "language": "english",
        "day_range": 9223372036854775807,
        "review_type": "all",
        "purchase_type": "all",
    }

    while n > 0:
        params["cursor"] = cursor.encode()
        params["num_per_page"] = min(100, n)
        n -= 100

        response = get_steam_reviews(appid, params)
        cursor = response["cursor"]
        reviews += response["reviews"]

        if len(response["reviews"]) < 100:
            break

    return reviews

# %% [markdown]
# ## Steam Store Game Data

# %%
def get_steam_game_data(params={"request": "top100forever", "format": "json"}):
    """
    Uses the steamspy API to return data for games on the steam marketplace
    default params are for the top 100 games by playtime forever, all games can be retrieved by changing the request param to all

    Parameters
    ----------

    Returns
    -------
    json
        Steam game data as json

    """
    base_url = "https://steamspy.com/api.php"

    response = requests.get(base_url, params=params)
    return response.json()

# %% [markdown]
# ## Steam Store Listing Data
#
# SotrefrontAPI data was found at https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI

# %%
def get_steam_store_data(appid):
    base_url = "https://store.steampowered.com/api/appdetails/"

    params = {"appids": appid}

    response = requests.get(base_url, params=params)
    return response.json()

# %% [markdown]
# # (Temp) Data to dataframes

# %%
game_df = pd.DataFrame().from_dict(get_steam_game_data(), orient="index")

# %%
review_list = []
store_data_list = []
for appid in game_df.appid:
    try:
        # Get Review Data for each appid in the dataframe
        response = get_n_reviews(appid, 10)
        for review in response:
            review_dict = {
                "appid": appid,
                "recommendationid": review["recommendationid"],
                "author": review["author"]["steamid"],
                "author_playtime_forever": review["author"][
                    "playtime_forever"
                ],
                "author_playtime_last_two_weeks": review["author"][
                    "playtime_last_two_weeks"
                ],
                "author_last_played": review["author"]["last_played"],
                "author_num_reviews": review["author"]["num_reviews"],
                "votes_up": review["votes_up"],
                "votes_funny": review["votes_funny"],
                "weighted_vote_score": review["weighted_vote_score"],
                "comment_count": review["comment_count"],
                "timestamp_created": review["timestamp_created"],
                "timestamp_updated": review["timestamp_updated"],
                "steam_purchase": review["steam_purchase"],
                "received_for_free": review["received_for_free"],
                "written_during_early_access": review[
                    "written_during_early_access"
                ],
                "review": review["review"],
            }

            review_list.append(review_dict)

        # Get storefront data for each appid
        storefront_response = get_steam_store_data(appid)
        store_data_list.append(storefront_response[str(appid)]["data"])
    except:
        print(appid)

review_df = pd.DataFrame(review_list)
storefront_df = pd.DataFrame(store_data_list)

# %%
get_n_reviews(10, 1)
# Out:
# [{'recommendationid': '22451084',
#   'author': {'steamid': '76561198097242611',
#    'num_games_owned': 1249,
#    'num_reviews': 11,
#    'playtime_forever': 216835,
#    'playtime_last_two_weeks': 243,
#    'playtime_at_review': 147092,
#    'last_played': 1697252981},
#   'language': 'english',
#   'review': 'Best FPS game i ever played',
#   'timestamp_created': 1460808481,
#   'timestamp_updated': 1460808481,
#   'voted_up': True,
#   'votes_up': 405,
#   'votes_funny': 0,
#   'weighted_vote_score': '0.976047277450561523',
#   'comment_count': 1,
#   'steam_purchase': False,
#   'received_for_free': False,
#   'written_during_early_access': False,
#   'hidden_in_steam_china': False,
#   'steam_china_location': ''}]

# %%
review_df.head()
# Out:
#    appid recommendationid             author  author_playtime_forever  \
# 0    570        139894673  76561198088348690                   624225
# 1    570        136918609  76561198147839040                   318322
# 2    570        114361523  76561198091204721                   785092
# 3    570        122685262  76561198364587737                        6
# 4    570        103119288  76561198870849422                      200
#
#    author_playtime_last_two_weeks  author_last_played  author_num_reviews  \
# 0                            2643          1697992631                   2
# 1                               0          1685701832                  59
# 2                               0          1649172225                   1
# 3                               0          1662282441                   3
# 4                               0          1668097004                  52
#
#    votes_up  votes_funny   weighted_vote_score  comment_count  \
# 0       422          129  0.961214721202850342              0
# 1      1481          971         0.96044921875             41
# 2       575           20  0.960387945175170898             44
# 3       819          577  0.958246469497680664              0
# 4       576          500  0.954392492771148682             14
#
#    timestamp_created  timestamp_updated  steam_purchase  received_for_free  \
# 0         1686495146         1686495146           False              False
# 1         1681842720         1681842720           False              False
# 2         1650750971         1650750971           False              False
# 3         1663940272         1663940272           False              False
# 4         1637398450         1637398450           False              False
#
#    written_during_early_access  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
#                                               review
# 0  This isn't a free game. Each match cost you a ...
# 1  This community is so nice i got a lot of tips ...
# 2  If you told me when I started playing dota 2 a...
# 3  This community is so nice i got a lot of tips ...
# 4  This community is so nice i got a lot of tips ...

# %%
game_df.head()
# Out:
#            appid                              name              developer  \
# 570          570                            Dota 2                  Valve
# 730          730  Counter-Strike: Global Offensive                  Valve
# 1172470  1172470                      Apex Legends  Respawn Entertainment
# 1063730  1063730                         New World           Amazon Games
# 578080    578080               PUBG: BATTLEGROUNDS          KRAFTON, Inc.
#
#                publisher score_rank  positive  negative  userscore  \
# 570                Valve              1707099    371654          0
# 730                Valve              6771631    924032          0
# 1172470  Electronic Arts               584895    148317          0
# 1063730     Amazon Games               186761     79224          0
# 578080     KRAFTON, Inc.              1284399    949723          0
#
#                              owners  average_forever  average_2weeks  \
# 570      200,000,000 .. 500,000,000                0               0
# 730      100,000,000 .. 200,000,000                0               0
# 1172470   50,000,000 .. 100,000,000                0               0
# 1063730   50,000,000 .. 100,000,000                0               0
# 578080    50,000,000 .. 100,000,000                0               0
#
#          median_forever  median_2weeks price initialprice discount      ccu
# 570                   0              0     0            0        0   705351
# 730                   0              0     0            0        0  1012735
# 1172470               0              0     0            0        0   275299
# 1063730               0              0  3999         3999        0    54857
# 578080                0              0     0            0        0   303830

# %%
storefront_df.head()
# Out:
#    type                 name  steam_appid required_age  is_free  \
# 0  game               Dota 2          570            0     True
# 1  game     Counter-Strike 2          730            0     True
# 2  game        Apex Legends™      1172470            0     True
# 3  game            New World      1063730            0    False
# 4  game  PUBG: BATTLEGROUNDS       578080            0     True
#
#                  dlc                               detailed_description  \
# 0  [1241930, 652720]  <strong>The most-played game on Steam.</strong...
# 1                NaN  For over two decades, Counter-Strike has offer...
# 2                NaN  <h1>Play Apex Legends Today!</h1><p><img src="...
# 3          [2487480]  <h1>New World - Azoth Edition</h1><p><img src=...
# 4                NaN  <strong>LAND, LOOT, SURVIVE!</strong><br>Play ...
#
#                                       about_the_game  \
# 0  <strong>The most-played game on Steam.</strong...
# 1  For over two decades, Counter-Strike has offer...
# 2  Conquer with character in Apex Legends, a free...
# 3  Explore a thrilling, open-world MMO filled wit...
# 4  <strong>LAND, LOOT, SURVIVE!</strong><br>Play ...
#
#                                    short_description  \
# 0  Every day, millions of players worldwide enter...
# 1  For over two decades, Counter-Strike has offer...
# 2  Apex Legends is the award-winning, free-to-pla...
# 3  Explore a thrilling, open-world MMO filled wit...
# 4  Play PUBG: BATTLEGROUNDS for free. Land on str...
#
#                                  supported_languages  ...  \
# 0  Bulgarian, Czech, Danish, Dutch, English<stron...  ...
# 1  Czech, Danish, Dutch, English<strong>*</strong...  ...
# 2  English<strong>*</strong>, French<strong>*</st...  ...
# 3  English<strong>*</strong>, French<strong>*</st...  ...
# 4  English, Korean, Simplified Chinese, French, G...  ...
#
#                                           background  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                       background_raw  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                  content_descriptors  \
# 0                         {'ids': [], 'notes': None}
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3  {'ids': [2, 5], 'notes': 'This Game may contai...
# 4                     {'ids': [2, 5], 'notes': None}
#
#                                         achievements controller_support  \
# 0                                                NaN                NaN
# 1  {'total': 1, 'highlighted': [{'name': 'A New B...                NaN
# 2  {'total': 12, 'highlighted': [{'name': 'The Pl...               full
# 3  {'total': 133, 'highlighted': [{'name': 'Repai...                NaN
# 4  {'total': 37, 'highlighted': [{'name': 'Last S...                NaN
#
#                                         legal_notice  \
# 0                                                NaN
# 1                                                NaN
# 2  Germany, Austria, and Switzerland only: EA’S P...
# 3  © 2021, Amazon.com, Inc. or its affiliates. Al...
# 4  © 2017 KRAFTON, Inc.<br />\r\nPUBG: BATTLEGROU...
#
#                           ext_user_account_notice       drm_notice  \
# 0                                             NaN              NaN
# 1                                             NaN              NaN
# 2  EA Account (Supports Linking to Steam Account)              NaN
# 3                                             NaN  Easy Anti-Cheat
# 4                                             NaN              NaN
#
#                                       price_overview demos
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3  {'currency': 'USD', 'initial': 3999, 'final': ...   NaN
# 4                                                NaN   NaN
#
# [5 rows x 41 columns]

# %%
get_steam_store_data(730)
# Out:
# {'730': {'success': True,
#   'data': {'type': 'game',
#    'name': 'Counter-Strike 2',
#    'steam_appid': 730,
#    'required_age': 0,
#    'is_free': True,
#    'detailed_description': 'For over two decades, Counter-Strike has offered an elite competitive experience, one shaped by millions of players from across the globe. And now the next chapter in the CS story is about to begin. This is Counter-Strike 2.<br><br>A free upgrade to CS:GO, Counter-Strike 2 marks the largest technical leap in Counter-Strike’s history. Built on the Source 2 engine, Counter-Strike 2 is modernized with realistic physically-based rendering, state of the art networking, and upgraded Community Workshop tools.<br><br>In addition to the classic objective-focused gameplay that Counter-Strike pioneered in 1999, Counter-Strike 2 features:<br><br><ul class="bb_ul"><li>All-new CS Ratings with the updated Premier mode<br></li><li>Global and Regional leaderboards<br></li><li>Upgraded and overhauled maps<br></li><li>Game-changing dynamic smoke grenades<br></li><li>Tick-rate-independent gameplay<br></li><li>Redesigned visual effects and audio<br></li><li>All items from CS:GO moving forward to CS2</li></ul>',
#    'about_the_game': 'For over two decades, Counter-Strike has offered an elite competitive experience, one shaped by millions of players from across the globe. And now the next chapter in the CS story is about to begin. This is Counter-Strike 2.<br><br>A free upgrade to CS:GO, Counter-Strike 2 marks the largest technical leap in Counter-Strike’s history. Built on the Source 2 engine, Counter-Strike 2 is modernized with realistic physically-based rendering, state of the art networking, and upgraded Community Workshop tools.<br><br>In addition to the classic objective-focused gameplay that Counter-Strike pioneered in 1999, Counter-Strike 2 features:<br><br><ul class="bb_ul"><li>All-new CS Ratings with the updated Premier mode<br></li><li>Global and Regional leaderboards<br></li><li>Upgraded and overhauled maps<br></li><li>Game-changing dynamic smoke grenades<br></li><li>Tick-rate-independent gameplay<br></li><li>Redesigned visual effects and audio<br></li><li>All items from CS:GO moving forward to CS2</li></ul>',
#    'short_description': 'For over two decades, Counter-Strike has offered an elite competitive experience, one shaped by millions of players from across the globe. And now the next chapter in the CS story is about to begin. This is Counter-Strike 2.',
#    'supported_languages': 'Czech, Danish, Dutch, English<strong>*</strong>, Finnish, French, German, Hungarian, Italian, Japanese, Korean, Norwegian, Polish, Portuguese - Portugal, Portuguese - Brazil, Romanian, Russian, Simplified Chinese, Spanish - Spain, Swedish, Thai, Traditional Chinese, Turkish, Bulgarian, Ukrainian, Greek, Spanish - Latin America, Vietnamese<br><strong>*</strong>languages with full audio support',
#    'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/730/header.jpg?t=1696513856',
#    'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/730/capsule_231x87.jpg?t=1696513856',
#    'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/730/capsule_184x69.jpg?t=1696513856',
#    'website': 'http://counter-strike.net/',
#    'pc_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows® 10<br></li><li><strong>Processor:</strong> 4 hardware CPU threads - Intel® Core™ i5 750 or higher<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> Video card must be 1 GB or more and should be a DirectX 11-compatible with support for Shader Model 5.0<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 85 GB available space</li></ul>'},
#    'mac_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> MacOS X 10.11 (El Capitan) or later<br></li><li><strong>Processor:</strong> Intel Core Duo Processor (2GHz or better)<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> ATI Radeon HD 2400 or better / NVIDIA 8600M or better<br></li><li><strong>Storage:</strong> 15 GB available space</li></ul>'},
#    'linux_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Ubuntu 20.04<br></li><li><strong>Processor:</strong> 4 hardware CPU threads - Intel® Core™ i5 750 or higher<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> AMD GCN+ or NVIDIA Kepler+ with up-to-date Vulkan drivers.  Support for VK_EXT_graphics_pipeline_library highly recommended.<br></li><li><strong>Storage:</strong> 85 GB available space<br></li><li><strong>Sound Card:</strong> Highly recommended</li></ul>'},
#    'developers': ['Valve'],
#    'publishers': ['Valve'],
#    'packages': [329385, 298963, 54029],
#    'package_groups': [{'name': 'default',
#      'title': 'Buy Counter-Strike 2',
#      'description': '',
#      'selection_text': 'Select a purchase option',
#      'save_text': '',
#      'display_type': 0,
#      'is_recurring_subscription': 'false',
#      'subs': [{'packageid': 298963,
#        'percent_savings_text': ' ',
#        'percent_savings': 0,
#        'option_text': 'Counter-Strike 2 - Free',
#        'option_description': '',
#        'can_get_free_license': '0',
#        'is_free_license': True,
#        'price_in_cents_with_discount': 0},
#       {'packageid': 54029,
#        'percent_savings_text': ' ',
#        'percent_savings': 0,
#        'option_text': 'Prime Status Upgrade - $14.99',
#        'option_description': '',
#        'can_get_free_license': '0',
#        'is_free_license': False,
#        'price_in_cents_with_discount': 1499}]}],
#    'platforms': {'windows': True, 'mac': False, 'linux': True},
#    'categories': [{'id': 1, 'description': 'Multi-player'},
#     {'id': 27, 'description': 'Cross-Platform Multiplayer'},
#     {'id': 29, 'description': 'Steam Trading Cards'},
#     {'id': 30, 'description': 'Steam Workshop'},
#     {'id': 35, 'description': 'In-App Purchases'},
#     {'id': 8, 'description': 'Valve Anti-Cheat enabled'},
#     {'id': 15, 'description': 'Stats'},
#     {'id': 41, 'description': 'Remote Play on Phone'},
#     {'id': 42, 'description': 'Remote Play on Tablet'},
#     {'id': 43, 'description': 'Remote Play on TV'}],
#    'genres': [{'id': '1', 'description': 'Action'},
#     {'id': '37', 'description': 'Free to Play'}],
#    'screenshots': [{'id': 0,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_796601d9d67faf53486eeb26d0724347cea67ddc.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_796601d9d67faf53486eeb26d0724347cea67ddc.1920x1080.jpg?t=1696513856'},
#     {'id': 1,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_d830cfd0550fbb64d80e803e93c929c3abb02056.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_d830cfd0550fbb64d80e803e93c929c3abb02056.1920x1080.jpg?t=1696513856'},
#     {'id': 2,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_13bb35638c0267759276f511ee97064773b37a51.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_13bb35638c0267759276f511ee97064773b37a51.1920x1080.jpg?t=1696513856'},
#     {'id': 3,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_0f8cf82d019c614760fd20801f2bb4001da7ea77.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_0f8cf82d019c614760fd20801f2bb4001da7ea77.1920x1080.jpg?t=1696513856'},
#     {'id': 4,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_ef82850f036dac5772cb07dbc2d1116ea13eb163.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_ef82850f036dac5772cb07dbc2d1116ea13eb163.1920x1080.jpg?t=1696513856'},
#     {'id': 5,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_76f6730dbb911650ba1f41c8e5b4bac638b5beea.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_76f6730dbb911650ba1f41c8e5b4bac638b5beea.1920x1080.jpg?t=1696513856'},
#     {'id': 6,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_808cdd373d78c3cf3a78e7026ebb1a15895e0670.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_808cdd373d78c3cf3a78e7026ebb1a15895e0670.1920x1080.jpg?t=1696513856'},
#     {'id': 7,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_ef98db5d5a4d877531a5567df082b0fb62d75c80.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_ef98db5d5a4d877531a5567df082b0fb62d75c80.1920x1080.jpg?t=1696513856'},
#     {'id': 8,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_2254a50f27951fb9028bc00b93a7f2ed7aac1e13.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_2254a50f27951fb9028bc00b93a7f2ed7aac1e13.1920x1080.jpg?t=1696513856'},
#     {'id': 9,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_54b9c26b028c84d5f8a5316f31ae6203953ed84d.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_54b9c26b028c84d5f8a5316f31ae6203953ed84d.1920x1080.jpg?t=1696513856'},
#     {'id': 10,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_1b3b5fd437939a7ed00a2155269e78994cb998d3.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_1b3b5fd437939a7ed00a2155269e78994cb998d3.1920x1080.jpg?t=1696513856'},
#     {'id': 11,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_352666c1949ce3966bd966d6ea5a1afd532257bc.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_352666c1949ce3966bd966d6ea5a1afd532257bc.1920x1080.jpg?t=1696513856'},
#     {'id': 12,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_63d2733b9b4ace01a41d5ba8afd653245d05d54a.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_63d2733b9b4ace01a41d5ba8afd653245d05d54a.1920x1080.jpg?t=1696513856'},
#     {'id': 13,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_fe70d46859593aef623a0614f4686e2814405035.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_fe70d46859593aef623a0614f4686e2814405035.1920x1080.jpg?t=1696513856'},
#     {'id': 14,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_bb2af3e83ac0385ff2055f2ab9697cdd83e351b7.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_bb2af3e83ac0385ff2055f2ab9697cdd83e351b7.1920x1080.jpg?t=1696513856'},
#     {'id': 15,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_fb8e5e2ae29ce64e2898315c66b5db08989e8f91.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_fb8e5e2ae29ce64e2898315c66b5db08989e8f91.1920x1080.jpg?t=1696513856'},
#     {'id': 16,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_0db84c628a798e38ca57d69abda119bee1358008.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_0db84c628a798e38ca57d69abda119bee1358008.1920x1080.jpg?t=1696513856'},
#     {'id': 17,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_18e9ea2715f0407ee05e206073927a648db60d73.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_18e9ea2715f0407ee05e206073927a648db60d73.1920x1080.jpg?t=1696513856'},
#     {'id': 18,
#      'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_2514675f364079b754b820cbc8b2e7c331d56a26.600x338.jpg?t=1696513856',
#      'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/730/ss_2514675f364079b754b820cbc8b2e7c331d56a26.1920x1080.jpg?t=1696513856'}],
#    'movies': [{'id': 256972298,
#      'name': 'Launch Trailer',
#      'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256972298/movie.293x165.jpg?t=1696005467',
#      'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256972298/movie480_vp9.webm?t=1696005467',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256972298/movie_max_vp9.webm?t=1696005467'},
#      'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256972298/movie480.mp4?t=1696005467',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256972298/movie_max.mp4?t=1696005467'},
#      'highlight': True},
#     {'id': 256970298,
#      'name': 'Moving Beyond Tick Rate',
#      'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256970298/movie.293x165.jpg?t=1696005475',
#      'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256970298/movie480_vp9.webm?t=1696005475',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256970298/movie_max_vp9.webm?t=1696005475'},
#      'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256970298/movie480.mp4?t=1696005475',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256970298/movie_max.mp4?t=1696005475'},
#      'highlight': True},
#     {'id': 256969703,
#      'name': 'Leveling Up',
#      'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256969703/movie.293x165.jpg?t=1696005483',
#      'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256969703/movie480_vp9.webm?t=1696005483',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256969703/movie_max_vp9.webm?t=1696005483'},
#      'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256969703/movie480.mp4?t=1696005483',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256969703/movie_max.mp4?t=1696005483'},
#      'highlight': True},
#     {'id': 256969690,
#      'name': 'Responsive Smokes',
#      'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256969690/movie.293x165.jpg?t=1696005491',
#      'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256969690/movie480_vp9.webm?t=1696005491',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256969690/movie_max_vp9.webm?t=1696005491'},
#      'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256969690/movie480.mp4?t=1696005491',
#       'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256969690/movie_max.mp4?t=1696005491'},
#      'highlight': True}],
#    'recommendations': {'total': 3983796},
#    'achievements': {'total': 1,
#     'highlighted': [{'name': 'A New Beginning',
#       'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/730/f75dd04fa12445a8ec43be65fa16ff1b8d2bf82e.jpg'}]},
#    'release_date': {'coming_soon': False, 'date': 'Aug 21, 2012'},
#    'support_info': {'url': '', 'email': ''},
#    'background': 'https://cdn.akamai.steamstatic.com/steam/apps/730/page_bg_generated_v6b.jpg?t=1696513856',
#    'background_raw': 'https://cdn.akamai.steamstatic.com/steam/apps/730/page.bg.jpg?t=1696513856',
#    'content_descriptors': {'ids': [2, 5],
#     'notes': 'Includes intense violence and blood.'}}}}
